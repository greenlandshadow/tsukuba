# %%
import folium


yatabe = [36.03203080856742, 140.07215010351732]


m = folium.Map(location=yatabe, zoom_start=15)

folium.CircleMarker(
    location=[36.03203080856742, 140.07215010351732],
    radius=180,
    color='black',
    fill_color='#ffff00'
).add_to(m)

group_1 = folium.FeatureGroup("1").add_to(m)
group_2 = folium.FeatureGroup("2").add_to(m)
group_3 = folium.FeatureGroup("3").add_to(m)


oudouya=[36.03027946074198, 140.05601216699895]
folium.Marker(oudouya,  tooltip="みどりの駅",icon=folium.Icon(color='red')).add_to(group_1)

url_img = 'http://ibaraki-museums.jp/category/assets_c/2016/08/45-thumb-400xauto-47-thumb-400xauto-354.jpg'
FORMAT_IMG = '<img src="{src}" />'
html =FORMAT_IMG.format(src=url_img)
fukurou=[36.036858075251054, 140.07458218903398]
folium.Marker(fukurou,popup=html,tooltip="つくば市谷田部郷土資料館",icon=folium.Icon(color='green')).add_to(group_2)

url_img1 = 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Tsukuba-City-Yatabe-Office.JPG/280px-Tsukuba-City-Yatabe-Office.JPG'
FORMAT_IMG = '<img src="{src}" />'
html1 =FORMAT_IMG.format(src=url_img1)
fukurou1=[36.03617789169835, 140.0750962484287]
folium.Marker(fukurou1,tooltip="旧谷田部町役場",icon=folium.Icon(color='green')).add_to(group_2)

fukurou2=[36.03203979832665, 140.07338526998475]
folium.Marker(fukurou2,popup=html1,tooltip="五角堂",icon=folium.Icon(color='black')).add_to(group_2)

fukurou3=[36.03390629942614, 140.07468160811865]
folium.Marker(fukurou3,tooltip="谷田部藩陣屋跡",icon=folium.Icon(color='black')).add_to(group_2)

fukurou3=[36.03305708825067, 140.07619276174253]
folium.Marker(fukurou3,tooltip="八坂神社",icon=folium.Icon(color='black')).add_to(group_2)

folium.CircleMarker(
    location=[36.0324085025669, 140.06229023929833],
    radius=90,
    color='black',
    fill_color='#ffa500'
).add_to(m)

folium.CircleMarker(
    location=[36.03027946074198, 140.05601216699895],
    radius=120,
    color='black',
    fill_color='#7fff00'
).add_to(m)
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6aa64fc73450ce5ff9d1d534e468087 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6aa64fc73450ce5ff9d1d534e468087&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6aa64fc73450ce5ff9d1d534e468087 = L.map(
#                 &quot;map_c6aa64fc73450ce5ff9d1d534e468087&quot;,
#                 {
#                     center: [36.03203080856742, 140.07215010351732],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ccce084440c7ff6e865cf366f8137c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c6aa64fc73450ce5ff9d1d534e468087);
#
#
#             var circle_marker_0bdd0181b73e8ff2b60720c4945190c0 = L.circleMarker(
#                 [36.03203080856742, 140.07215010351732],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 180, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c6aa64fc73450ce5ff9d1d534e468087);
#
#
#             var feature_group_2334679463f387450d279daa84bf2329 = L.featureGroup(
#                 {}
#             ).addTo(map_c6aa64fc73450ce5ff9d1d534e468087);
#
#
#             var marker_436047bd1813921fb0c6dbb349b79f6f = L.marker(
#                 [36.03027946074198, 140.05601216699895],
#                 {}
#             ).addTo(feature_group_2334679463f387450d279daa84bf2329);
#
#
#             var icon_b3eaf6e900d6de04afa2551abaa9e6af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_436047bd1813921fb0c6dbb349b79f6f.setIcon(icon_b3eaf6e900d6de04afa2551abaa9e6af);
#
#
#             marker_436047bd1813921fb0c6dbb349b79f6f.bindTooltip(
#                 `&lt;div&gt;
#                      みどりの駅
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var feature_group_124413c5541af53fc49ab38e2046bbf5 = L.featureGroup(
#                 {}
#             ).addTo(map_c6aa64fc73450ce5ff9d1d534e468087);
#
#
#             var marker_76ae118c4acf234a5d3a9e2b079feab8 = L.marker(
#                 [36.036858075251054, 140.07458218903398],
#                 {}
#             ).addTo(feature_group_124413c5541af53fc49ab38e2046bbf5);
#
#
#             var icon_d825474ccd84d02804b3a3284f8108b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_76ae118c4acf234a5d3a9e2b079feab8.setIcon(icon_d825474ccd84d02804b3a3284f8108b7);
#
#
#         var popup_a6382e48c3ac30710a1e1f857365839d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e81f57e0c2c739dbc2700d598d88d1a8 = $(`&lt;div id=&quot;html_e81f57e0c2c739dbc2700d598d88d1a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&quot;http://ibaraki-museums.jp/category/assets_c/2016/08/45-thumb-400xauto-47-thumb-400xauto-354.jpg&quot; /&gt;&lt;/div&gt;`)[0];
#                 popup_a6382e48c3ac30710a1e1f857365839d.setContent(html_e81f57e0c2c739dbc2700d598d88d1a8);
#
#
#
#         marker_76ae118c4acf234a5d3a9e2b079feab8.bindPopup(popup_a6382e48c3ac30710a1e1f857365839d)
#         ;
#
#
#
#
#             marker_76ae118c4acf234a5d3a9e2b079feab8.bindTooltip(
#                 `&lt;div&gt;
#                      つくば市谷田部郷土資料館
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4b194d1bae3fa19dd2b49c061fced9fd = L.marker(
#                 [36.03617789169835, 140.0750962484287],
#                 {}
#             ).addTo(feature_group_124413c5541af53fc49ab38e2046bbf5);
#
#
#             var icon_b6b890a3431b199dd3c225d8eef787b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;gly
