# %%
import folium


yatabe = [36.03203080856742, 140.07215010351732]


m = folium.Map(location=yatabe, zoom_start=15)

folium.CircleMarker(
    location=[36.03203080856742, 140.07215010351732],
    radius=180,
    color='black',
    fill_color='#ffff00'
).add_to(m)

group_1 = folium.FeatureGroup("1").add_to(m)
group_2 = folium.FeatureGroup("2").add_to(m)
group_3 = folium.FeatureGroup("3").add_to(m)


oudouya=[36.03027946074198, 140.05601216699895]
folium.Marker(oudouya,  tooltip="みどりの駅",icon=folium.Icon(color='red')).add_to(group_1)

url_img = 'data:image/jpeg;base64,...'
FORMAT_IMG = '<img src="{src}" />'
html =FORMAT_IMG.format(src=url_img)
fukurou=[36.036858075251054, 140.07458218903398]
folium.Marker(fukurou,popup=html,tooltip="つくば市谷田部郷土資料館",icon=folium.Icon(color='green')).add_to(group_2)

url_img1 = 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Tsukuba-City-Yatabe-Office.JPG/280px-Tsukuba-City-Yatabe-Office.JPG'
FORMAT_IMG = '<img src="{src}" />'
html1 =FORMAT_IMG.format(src=url_img1)
fukurou1=[36.03617789169835, 140.0750962484287]
folium.Marker(fukurou1,popup=html1,tooltip="旧谷田部町役場",icon=folium.Icon(color='green')).add_to(group_2)

url_img2 = 'https://pbs.twimg.com/media/GQSnW6gbYAA7j49?format=jpg&name=360x360'
FORMAT_IMG = '<img src="{src}" />'
html2 =FORMAT_IMG.format(src=url_img2)
fukurou2=[36.03203979832665, 140.07338526998475]
folium.Marker(fukurou2,popup=html2,tooltip="五角堂",icon=folium.Icon(color='black')).add_to(group_2)

url_img3 = 'https://pbs.twimg.com/media/GQSnW6maAAAS2It?format=jpg&name=360x360'
FORMAT_IMG = '<img src="{src}" />'
html3 =FORMAT_IMG.format(src=url_img3)
fukurou3=[36.03390629942614, 140.07468160811865]
folium.Marker(fukurou3,tooltip="谷田部藩陣屋跡",popup=html3,icon=folium.Icon(color='black')).add_to(group_2)

url_img4 = 'https://pbs.twimg.com/media/GQSnW6fboAA3Uff?format=jpg&name=360x360'
FORMAT_IMG = '<img src="{src}" />'
html4 =FORMAT_IMG.format(src=url_img4)
fukurou4=[36.03305708825067, 140.07619276174253]
folium.Marker(fukurou4,tooltip="八坂神社",popup=html4,icon=folium.Icon(color='black')).add_to(group_2)

url_img5 = 'data:image/jpeg;base64,...'
FORMAT_IMG = '<img src="{src}" />'
html5 =FORMAT_IMG.format(src=url_img5)
fukurou5=[36.02650186138289, 140.07400349205906]
folium.Marker(fukurou5,tooltip="不動並木跡",popup=html5,icon=folium.Icon(color='black')).add_to(group_2)

folium.CircleMarker(
    location=[36.0324085025669, 140.06229023929833],
    radius=90,
    color='black',
    fill_color='#ffa500'
).add_to(m)

folium.CircleMarker(
    location=[36.03027946074198, 140.05601216699895],
    radius=120,
    color='black',
    fill_color='#7fff00'
).add_to(m)
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save(outfile="map.html")
